# %% [markdown]
# <a href="https://colab.research.google.com/github/Faisfaiz/machine-learning/blob/main/weeks1/Basic_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex2 import *
print("Setup Complete")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-1e848246840e> in <cell line: 2>()
#       1 # Set up code checking
# ----> 2 from learntools.core import binder
#       3 binder.bind(globals())
#       4 from learntools.machine_learning.ex2 import *
#       5 print("Setup Complete")
#
# ModuleNotFoundError: No module named 'learntools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Faishal Anwar
# 1103204096

# %%
import pandas as pd

# %%
# save filepath to variable for easier access
melbourne_file_path = '/melb_data.csv'
# read the data and store data in DataFrame titled melbourne_data
melbourne_data = pd.read_csv(melbourne_file_path)
# print a summary of the data in Melbourne data
melbourne_data.describe()
# Out:
#            Distance      Postcode      Bedroom2      Bathroom           Car  \
# count  20352.000000  20352.000000  20352.000000  20352.000000  20228.000000
# mean      10.694777   3108.271669      2.967866      1.548054      1.734279
# std        6.359326    101.104253      2.347998      1.041637     13.593471
# min        0.000000      2.000000      0.000000      0.000000      0.000000
# 25%        6.300000   3046.000000      2.000000      1.000000      1.000000
# 50%        9.900000   3087.000000      3.000000      1.000000      2.000000
# 75%       13.800000   3150.000000      4.000000      2.000000      2.000000
# max       48.100000   3977.000000    308.000000    113.000000   1930.000000
#
#        BuildingArea     YearBuilt     Lattitude    Longtitude  Propertycount
# count  10443.000000  12046.000000  20352.000000  20351.000000   20351.000000
# mean     154.335528   1965.806407    -37.535531    144.997946    7333.854602
# ...

# %%
import pandas as pd

# Path of the file to read
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

# Fill in the line below to read the file into a variable home_data
home_data = ____

# Call line below with no argument to check that you've loaded the data correctly
step_1.check()

# %%
# Lines below will give you a hint or solution code
#step_1.hint()
#step_1.solution()

# %%
# What is the average lot size (rounded to nearest integer)?
avg_lot_size = ____

# As of today, how old is the newest home (current year - the date in which it was built)
newest_home_age = ____

# Checks your answers
step_2.check()

# %%
#step_2.hint()
#step_2.solution()
